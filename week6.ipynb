# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # I -PLOTTING FRUIT DATA USING PANDASN -MATPLOTLIB - SEABORN

# %% [markdown]
# # 1 -Importing the Main Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2 - Importing the Dataset on the Kaggle - Transforming the Dataset into dataframe

# %%
 df = pd.read_csv('/kaggle/input/fruit-test-data/FruitTestData.csv')

# %%
df.head()

# %%
df.tail(3)

# %%
df.describe()

# %%
df.info()

# %% [markdown]
# # 3 - Plotting Fruit Data with Matplotlib

# %%
df.plot(x = 'fruit_names' , y= 'sold_numbers',color = '#5b227c')
plt.title('Plotting Fruit Data' , color = '#18070a', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 20})
plt.xlabel('Fruit Sold' , color = '#ff0000', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 16})
plt.ylabel('sold remaining' , color = '#ff0000', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 16})
plt.show()

# %%
df.fillna(0,inplace = True)
df

# %%
df.plot(x = 'fruit_names' , y= 'sold_numbers',color = '#5b227c')
plt.title('Plotting Fruit Data' , color = '#18070a', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 20})
plt.xlabel('Fruit Sold' , color = '#ff0000', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 16})
plt.ylabel('sold numbers' , color = '#ff0000', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 16})
plt.show()

# %%
df.plot(x = 'fruit_names' , y= ['sold_numbers','remaining_numbers'],color = '#5b227c')
plt.title('Plotting Fruit Data' , color = '#18070a', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 20})
plt.xlabel('Fruit Sold' , color = '#ff0000', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 16})
plt.ylabel('sold numbers' , color = '#ff0000', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 16})
plt.show()

# %%
df.plot(x = 'fruit_names' , y= ['sold_numbers','remaining_numbers'],kind = 'bar')
plt.title('Plotting Fruit Data' , color = '#18070a', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 20})
plt.xlabel('Fruit Sold' , color = '#ff0000', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 16})
plt.ylabel('numbers' , color = '#ff0000', fontdict = {'fontname' : 'Arial', 'fontweight':'bold','fontsize': 16})
plt.show()

# %% [markdown]
# # II -PLOTTING IRIS DATA WITH SEABORN - MATPLOTLIB

# %% [markdown]
# # 2.1 - Importing the Main Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## 2.2  - Transformig the dataset into dataframe

# %%
df = pd.read_csv('/kaggle/input/iris-data/IRIS_data.csv')
df

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## 2.3 Plotting with Seaborn

# %%
sns.pairplot(df, hue = 'species')

# %% [markdown]
# # 2.4 Transforming the data

# %%
data = df.values
X = data[:,0:4]
Y = data[:,4]

# %% [markdown]
# # 2.5 Model Selection

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y)

# %%
from sklearn.cluster
